# %% [markdown]
# # Compile the Data
#
# The source data is maintained in a relational database with each table provided as an individual json. The following code is going to pull in the necessary tables to populate our dataframe. It will then perform cleaning and reformatting of some fields to create a master copy of all the relevant data. This will allow me to query based on league, team, and players to get the focused data I need for visualizations and predictions. Each of those processes will further modify the dataframe to account for the end goal.

# %% [markdown]
# ## 1. Create the primary dataframe
# #### 1.1 Events data
# #### 1.2 Match data
# #### 1.3 Join Match and Event data
# ## 2. Supporting tables
# #### 2.1 Team data
# #### 2.2 Player data
# #### 2.3 Competition data
# ## 3. Clean-up the final dataframe
# #### 3.1 Create coordinate columns
# #### 3.2 Create positional grids
# #### 3.3 Address missing values
# ## 4. Export to csv

# %%
import pandas as pd
import requests
import json
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Create the primary dataframe

# %%
# a function to compile the tables for all the different competitions into a single dataframe
def buildDF(dataframe, jsons):
    for i in jsons:
        print(i)
        temp = pd.read_json(i)
        frame = [temp, dataframe]
        dataframe = pd.concat(frame)
        
    return dataframe

# %%
# create initial dataframes for events and matches using the England data
events= pd.read_json('events_England.json')
matches= pd.read_json('matches_England.json')

# %% [markdown]
# ### 1.1 Events data

# %%
# compile all the events data from the various leagues
leagues = ['events_France.json',
           'events_Germany.json',
           'events_Italy.json',
           'events_Spain.json']

events = buildDF(events, leagues)
# Out:
# events_France.json
# events_Germany.json
# events_Italy.json
# events_Spain.json

# %%
events.head()
# Out:
#    eventId subEventName            tags  playerId  \
# 0        8  Simple pass  [{'id': 1801}]      3542
# 1        8  Simple pass  [{'id': 1801}]    274435
# 2        8  Simple pass  [{'id': 1801}]    364860
# 3        8  Simple pass  [{'id': 1801}]      3534
# 4        8  Simple pass  [{'id': 1801}]      3695
#
#                                   positions  matchId eventName  teamId  \
# 0  [{'y': 61, 'x': 37}, {'y': 50, 'x': 50}]  2565548      Pass     682
# 1  [{'y': 50, 'x': 50}, {'y': 30, 'x': 45}]  2565548      Pass     682
# 2  [{'y': 30, 'x': 45}, {'y': 12, 'x': 38}]  2565548      Pass     682
# 3  [{'y': 12, 'x': 38}, {'y': 69, 'x': 32}]  2565548      Pass     682
# 4  [{'y': 69, 'x': 32}, {'y': 37, 'x': 31}]  2565548      Pass     682
#
#   matchPeriod   eventSec subEventId         id
# 0          1H   2.994582         85  180864419
# 1          1H   3.137020         85  180864418
# 2          1H   6.709668         85  180864420
# 3          1H   8.805497         85  180864421
# 4          1H  14.047492         85  180864422

# %%
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3071395 entries, 0 to 643149
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   eventId       int64
#  1   subEventName  object
#  2   tags          object
#  3   playerId      int64
#  4   positions     object
#  5   matchId       int64
#  6   eventName     object
#  7   teamId        int64
#  8   matchPeriod   object
#  9   eventSec      float64
#  10  subEventId    object
#  11  id            int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 304.6+ MB

# %% [markdown]
# ### 1.2 Match data

# %%
# compile all the match data from the various leagues
leagueMatches = ['matches_England.json',
                 'matches_France.json',
                 'matches_Germany.json',
                 'matches_Italy.json',
                 'matches_Spain.json']


matches= buildDF(matches, leagueMatches)
# Out:
# matches_England.json
# matches_France.json
# matches_Germany.json
# matches_Italy.json
# matches_Spain.json

# %%
matches.head()
# Out:
#    status  roundId  gameweek  \
# 0  Played  4406122        38
# 1  Played  4406122        38
# 2  Played  4406122        38
# 3  Played  4406122        38
# 4  Played  4406122        38
#
#                                            teamsData  seasonId  \
# 0  {'676': {'scoreET': 0, 'coachId': 92894, 'side...    181144
# 1  {'679': {'scoreET': 0, 'coachId': 3427, 'side'...    181144
# 2  {'691': {'scoreET': 0, 'coachId': 444778, 'sid...    181144
# 3  {'674': {'scoreET': 0, 'coachId': 210074, 'sid...    181144
# 4  {'675': {'scoreET': 0, 'coachId': 275283, 'sid...    181144
#
#                dateutc  winner                        venue     wyId  \
# 0  2018-05-20 18:45:00     676                     Camp Nou  2565922
# 1  2018-05-20 16:30:00       0  Estadio Wanda Metropolitano  2565925
# 2  2018-05-20 14:15:00     691        San Mam\u00e9s Barria  2565919
# 3  2018-05-20 10:00:00     674          Estadio de Mestalla  2565924
# 4  2018-05-19 18:45:00       0  Estadio de la Cer\u00e1mica  2565927
#
#                                         label  \
# 0            Barcelona - Real Sociedad, 1 - 0
# 1         Atl\u00e9tico Madrid - Eibar, 2 - 2
# 2             Athletic Club - Espanyol, 0 - 1
# 3  Valencia - Deportivo La Coru\u00f1a, 2 - 1
# 4             Villarreal - Real Madrid, 2 - 2
#
#                                 date  \
# 0   May 20, 2018 at 8:45:00 PM GMT+2
# 1   May 20, 2018 at 6:30:00 PM GMT+2
# 2   May 20, 2018 at 4:15:00 PM GMT+2
# 3  May 20, 2018 at 12:00:00 PM GMT+2
# 4   May 19, 2018 at 8:45:00 PM GMT+2
#
#                                             referees duration  competitionId
# 0  [{'refereeId': 398931, 'role': 'referee'}, {'r...  Regular            795
# 1  [{'refereeId': 395056, 'role': 'referee'}, {'r...  Regular            795
# 2  [{'refereeId': 384957, 'role': 'referee'}, {'r...  Regular            795
# 3  [{'refereeId': 398913, 'role': 'referee'}, {'r...  Regular            795
# 4  [{'refereeId': 395085, 'role': 'referee'}, {'r...  Regular            795

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2206 entries, 0 to 379
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status         2206 non-null   object
#  1   roundId        2206 non-null   int64
#  2   gameweek       2206 non-null   int64
#  3   teamsData      2206 non-null   object
#  4   seasonId       2206 non-null   int64
#  5   dateutc        2206 non-null   object
#  6   winner         2206 non-null   int64
#  7   venue          2206 non-null   object
#  8   wyId           2206 non-null   int64
#  9   label          2206 non-null   object
#  10  date           2206 non-null   object
#  11  referees       2206 non-null   object
#  12  duration       2206 non-null   object
#  13  competitionId  2206 non-null   int64
# dtypes: int64(6), object(8)
# memory usage: 258.5+ KB

# %%
# change the wyId column to matchID to allow for joining the match data to the event data
matches.rename({'wyId': 'matchId'}, axis=1, inplace=True)

# %%
matches[matches.gameweek == 27]
# Out:
#      status  roundId  gameweek  \
# 110  Played  4406122        27
# 111  Played  4406122        27
# 112  Played  4406122        27
# 113  Played  4406122        27
# 114  Played  4406122        27
# 115  Played  4406122        27
# 116  Played  4406122        27
# 117  Played  4406122        27
# 118  Played  4406122        27
# 119  Played  4406122        27
# 80   Played  4406278        27
# 81   Played  4406278        27
# 82   Played  4406278        27
# 83   Played  4406278        27
# 112  February 11, 2018 at 3:15:00 PM GMT+1
# 113  February 11, 2018 at 1:00:00 PM GMT+1
# 114  February 10, 2018 at 6:30:00 PM GMT+1
# 115  February 10, 2018 at 4:00:00 PM GMT+1
# 116  February 10, 2018 at 4:00:00 PM GMT+1
# 117  February 10, 2018 at 4:00:00 PM GMT+1
# 118  February 10, 2018 at 4:00:00 PM GMT+1
# 119  February 10, 2018 at 1:30:00 PM GMT+1
# 110  February 12, 2018 at 9:00:00 PM GMT+1
# 111  February 11, 2018 at 5:30:00 PM GMT+1
# 112  February 11, 2018 at 3:15:00 PM GMT+1
# 113  February 11, 2018 at 1:00:00 PM GMT+1
# 114  February 10, 2018 at 6:30:00 PM GMT+1
# 115  February 10, 2018 at 4:00:00 PM GMT+1
# 116  February 10, 2018 at 4:00:00 PM GMT+1
# 117  February 10, 2018 at 4:00:00 PM GMT+1
# 118  February 10, 2018 at 4:00:00 PM GMT+1
# 119  February 10, 2018 at 1:30:00 PM GMT+1
#
#                                               referees duration  competitionId
# 110  [{'refereeId': 395078, 'role': 'referee'}, {'r...  Regular            795
# 111  [{'refereeId': 378950, 'role': 'referee'}, {'r...  Regular            795
# 112  [{'refereeId': 378994, 'role': 'referee'}, {'r...  Regular            795
# 113  [{'refereeId': 381927, 'role': 'referee'}, {'r...  Regular            795
# 114  [{'refereeId': 398945, 'role': 'referee'}, {'r...  Regular            795
# 115  [{'refereeId': 420995, 'role': 'referee'}, {'r...  Regular            795
# 116  [{'refereeId': 385473, 'role': 'referee'}, {'r...  Regular            795
# 117  [{'refereeId': 381854, 'role': 'referee'}, {'r...  Regular            795
# 118  [{'refereeId': 384923, 'role': 'referee'}, {'r...  Regular            795
# 119  [{'refereeId': 460924, 'role': 'referee'}, {'r...  Regular            795
# 80   [{'refereeId': 377241, 'role': 'referee'}, {'r...  Regular            524
# 81   [{'refereeId': 377256, 'role': 'referee'}, {'r...  Regular            524
# 82   [{'refereeId': 377210, 'role': 'referee'}, {'r...  Regular            524
# 83   [{'refereeId': 377244, 'role': 'referee'}, {'r...  Regular            524
# 84   [{'refereeId': 377263, 'role': 'referee'}, {'r...  Regular            524
# 85   [{'refereeId': 377231, 'role': 'referee'}, {'r...  Regular            524
# 86   [{'refereeId': 377246, 'role': 'referee'}, {'r...  Regular            524
# 118  [{'refereeId': 377247, 'role': 'referee'}, {'r...  Regular            524
# 119  [{'refereeId': 377231, 'role': 'referee'}, {'r...  Regular            524
# 120  [{'refereeId': 377206, 'role': 'referee'}, {'r...  Regular            524
# 63   [{'refereeId': 381840, 'role': 'referee'}, {'r...  Regular            426
# 64   [{'refereeId': 385544, 'role': 'referee'}, {'r...  Regular            426
# 65   [{'refereeId': 379378, 'role': 'referee'}, {'r...  Regular            426
# 66   [{'refereeId': 383336, 'role': 'referee'}, {'r...  Regular            426
# 67   [{'refereeId': 378970, 'role': 'referee'}, {'r...  Regular            426
# 68   [{'refereeId': 378945, 'role': 'referee'}, {'r...  Regular            426
# 69   [{'refereeId': 379444, 'role': 'referee'}, {'r...  Regular            426
# 70   [{'refereeId': 387272, 'role': 'referee'}, {'r...  Regular            426
# 71   [{'refereeId': 381858, 'role': 'referee'}, {'r...  Regular            426
# 110  [{'refereeId': 386297, 'role': 'referee'}, {'r...  Regular            412
# 111  [{'refereeId': 384953, 'role': 'referee'}, {'r...  Regular            412
# 112  [{'refereeId': 381843, 'role': 'referee'}, {'r...  Regular            412
# 113  [{'refereeId': 460026, 'role': 'referee'}, {'r...  Regular            412
# 114  [{'refereeId': 385529, 'role': 'referee'}, {'r...  Regular            412
# 115  [{'refereeId': 385528, 'role': 'referee'}, {'r...  Regular            412
# 116  [{'refereeId': 385484, 'role': 'referee'}, {'r...  Regular            412
# 117  [{'refereeId': 385496, 'role': 'referee'}, {'r...  Regular            412
# 118  [{'refereeId': 378948, 'role': 'referee'}, {'r...  Regular            412
# 119  [{'refereeId': 378976, 'role': 'referee'}, {'r...  Regular            412
# 110  [{'refereeId': 381853, 'role': 'referee'}, {'r...  Regular            364
# 111  [{'refereeId': 384888, 'role': 'referee'}, {'r...  Regular            364
# 112  [{'refereeId': 378951, 'role': 'referee'}, {'r...  Regular            364
# 113  [{'refereeId': 384965, 'role': 'referee'}, {'r...  Regular            364
# 114  [{'refereeId': 385916, 'role': 'referee'}, {'r...  Regular            364
# 115  [{'refereeId': 381851, 'role': 'referee'}, {'r...  Regular            364
# 116                                                 []  Regular            364
# 117  [{'refereeId': 385911, 'role': 'referee'}, {'r...  Regular            364
# 118  [{'refereeId': 408156, 'role': 'referee'}, {'r...  Regular            364
# 119  [{'refereeId': 378952, 'role': 'referee'}, {'r...  Regular            364
# 110  [{'refereeId': 381853, 'role': 'referee'}, {'r...  Regular            364
# 111  [{'refereeId': 384888, 'role': 'referee'}, {'r...  Regular            364
# 112  [{'refereeId': 378951, 'role': 'referee'}, {'r...  Regular            364
# 113  [{'refereeId': 384965, 'role': 'referee'}, {'r...  Regular            364
# 114  [{'refereeId': 385916, 'role': 'referee'}, {'r...  Regular            364
# 115  [{'refereeId': 381851, 'role': 'referee'}, {'r...  Regular            364
# 116                                                 []  Regular            364
# 117  [{'refereeId': 385911, 'role': 'referee'}, {'r...  Regular            364
# 118  [{'refereeId': 408156, 'role': 'referee'}, {'r...  Regular            364
# 119  [{'refereeId': 378952, 'role': 'referee'}, {'r...  Regular            364

# %% [markdown]
# ### 1.3 Join matches and events

# %%
soccer = pd.merge(matches, events, on=['matchId'], how='outer')

# %%
soccer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3714545 entries, 0 to 3714544
# Data columns (total 25 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   status         object
#  1   roundId        int64
#  2   gameweek       int64
#  3   teamsData      object
#  4   seasonId       int64
#  5   dateutc        object
#  6   winner         int64
#  7   venue          object
#  8   matchId        int64
#  9   label          object
#  10  date           object
#  11  referees       object
#  12  duration       object
#  13  competitionId  int64
#  14  eventId        int64
#  15  subEventName   object
#  16  tags           object
#  17  playerId       int64
#  18  positions      object
#  19  eventName      object
#  20  teamId         int64
#  21  matchPeriod    object
#  22  eventSec       float64
#  23  subEventId     object
#  24  id             int64
# dtypes: float64(1), int64(10), object(14)
# memory usage: 736.8+ MB

# %% [markdown]
# ## 2. Supporting tables
# Loading the json files that represent teams, competitions, and players. These have corresponding id's that can be used to replace those reference values to the actual names.

# %%
import codecs

#Load the teams json file
teams= pd.read_json(codecs.open('teams.json', 'r','unicode_escape'))
#Load the competitions json file
competitions = pd.read_json('competitions.json')
#Load player json file
players = pd.read_json(codecs.open('players.json', 'r','unicode_escape'))

# %% [markdown]
# ### 2.1 Team data

# %%
teams.head()
# Out:
#                   city              name  wyId                  officialName  \
# 0  Newcastle upon Tyne  Newcastle United  1613           Newcastle United FC
# 1                 Vigo     Celta de Vigo   692       Real Club Celta de Vigo
# 2            Barcelona          Espanyol   691  Reial Club Deportiu Espanyol
# 3      Vitoria-Gasteiz  Deportivo Alavés   696              Deportivo Alavés
# 4             Valencia           Levante   695                    Levante UD
#
#                                                 area  type
# 0  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 1  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 4  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club

# %%
#we only need the team name
teams.drop(['city','officialName','area','type'], axis=1, inplace=True)

# rename wyId to teamId
teams.rename({'wyId': 'teamId'}, axis=1, inplace=True)

# %%
teams.head()
# Out:
#                name  teamId
# 0  Newcastle United    1613
# 1     Celta de Vigo     692
# 2          Espanyol     691
# 3  Deportivo Alavés     696
# 4           Levante     695

# %%
teams.name.unique()
# Out:
# array(['Newcastle United', 'Celta de Vigo', 'Espanyol',
#        'Deportivo Alavés', 'Levante', 'Troyes', 'Getafe',
#        "Borussia M'gladbach", 'Huddersfield Town', 'Athletic Club',
#        'Atlético Madrid', 'Olympique Lyonnais', 'PSG', 'Valencia',
#        'Real Madrid', 'Barcelona', 'Las Palmas', 'Leganés', 'SPAL',
#        'Swansea City', 'Olympique Marseille', 'Nantes', 'Nice', 'Rennes',
#        'Strasbourg', 'Eibar', 'AFC Bournemouth', 'Brighton & Hove Albion',
#        'Werder Bremen', 'Bayer Leverkusen', 'Borussia Dortmund',
#        'Bayern München', 'Stuttgart', 'Schalke 04', 'Milan', 'Angers',
#        'Juventus', 'Roma', 'Sassuolo', 'Burnley', 'Bordeaux',
#        'Hannover 96', 'Dijon', 'Hertha BSC', 'Wolfsburg', 'Hamburger SV',
#        'Freiburg', 'Bologna', 'Metz', 'Sampdoria', 'Chievo', 'Lazio',
#        'Udinese', 'Internazionale', 'Leicester City', 'West Ham United',
#        'Stoke City', 'Benevento', 'Saint-Étienne', 'Girona', 'Watford',
#        'Hoffenheim', 'Cagliari', 'Atalanta', 'Fiorentina', 'Everton',
#        'West Bromwich Albion', 'Manchester City', 'Tottenham Hotspur',
#        'Augsburg', 'Crystal Palace', 'Monaco', 'Mainz 05', 'Lille',
#        'Eintracht Frankfurt', 'Southampton', 'Köln', 'Liverpool',
#        'Chelsea', 'Manchester United', 'Torino', 'Napoli',
#        'Deportivo La Coruña', 'RB Leipzig', 'Arsenal', 'Caen', 'Toulouse',
#        'Montpellier', 'Guingamp', 'Amiens SC', 'Crotone', 'Hellas Verona',
#        'Genoa', 'Real Betis', 'Real Sociedad', 'Sevilla', 'Málaga',
#        'Villarreal', 'Korea Republic', 'Hungary', 'Turkey', 'Russia',
#        'Sweden', 'Tunisia', 'Brazil', 'Germany', 'Albania', 'Romania',
#        'Ukraine', 'Morocco', 'Slovakia', 'Colombia', 'Panama',
#        'Australia', 'Argentina', 'Northern Ireland', 'Portugal',
#        'Belgium', 'Denmark', 'Uruguay', 'Wales', 'Costa Rica', 'England',
#        'Egypt', 'Japan', 'Iran', 'Austria', 'Iceland', 'Croatia',
#        'Mexico', 'Republic of Ireland', 'Czech Republic', 'Senegal',
#        'Italy', 'Peru', 'France', 'Saudi Arabia', 'Spain', 'Serbia',
#        'Switzerland', 'Poland', 'Nigeria'], dtype=object)

# %%
# creating a dictionary to use replace teamIds with names in the primary dataframe
teamName = teams.set_index('teamId').to_dict()['name']

# use the dictionary to remap the teamId and winner to the team names from the teams dataframe
soccer.replace({'teamId':teamName}, inplace=True)
soccer.replace({'winner':teamName}, inplace=True)

# %% [markdown]
# ### 2.2 Players data

# %%
players.head()
# Out:
#                                         passportArea  weight  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...      78
# 1  {'name': 'Senegal', 'id': '686', 'alpha3code':...      73
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...      72
# 3  {'name': 'Senegal', 'id': '686', 'alpha3code':...      82
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...      84
#
#            firstName middleName  lastName currentTeamId   birthDate  height  \
# 0              Harun                Tekin          4502  1989-06-17     187
# 1             Malang                 Sarr          3775  1999-01-23     182
# 2               Over             Mandanda          3772  1998-10-26     176
# 3  Alfred John Momar              N'Diaye           683  1990-03-06     187
# 4           Ibrahima               Konaté          2975  1999-05-25     192
#
#                                                 role  \
# 0  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 1  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
# 2  {'code2': 'GK', 'code3': 'GKP', 'name': 'Goalk...
# 3  {'code2': 'MD', 'code3': 'MID', 'name': 'Midfi...
# 4  {'code2': 'DF', 'code3': 'DEF', 'name': 'Defen...
#
#                                            birthArea    wyId   foot  \
# 0  {'name': 'Turkey', 'id': '792', 'alpha3code': ...   32777  right
# 1  {'name': 'France', 'id': '250', 'alpha3code': ...  393228   left
# 2  {'name': 'France', 'id': '250', 'alpha3code': ...  393230
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...   32793  right
# 4  {'name': 'France', 'id': '250', 'alpha3code': ...  393247  right
#
#      shortName currentNationalTeamId
# 0     H. Tekin                  4687
# 1      M. Sarr                  4423
# 2  O. Mandanda                  null
# 3   A. N'Diaye                 19314
# 4    I. Konaté                  null

# %%
# pull out just the first position code from the role column
players['position'] = [x['code2'] for x in players['role']]

# we only need the player's name, role, and wyId
players= players[['lastName','position','wyId']]

# rename wyId to teamId and position to role
players.rename({'wyId': 'playerId','position': 'role'}, axis=1, inplace=True)

# %%
len(players.lastName.unique())
# Out:
# 3414

# %%
# merge the player data in with the soccer dataframe
soccer = pd.merge(soccer, players, on=['playerId'], how='outer')
#drop the playerId column
soccer.drop(['playerId'], axis=1, inplace=True)

# %% [markdown]
# ### 2.3 Competition data

# %%
competitions.head()
# Out:
#                      name  wyId           format  \
# 0  Italian first division   524  Domestic league
# 1  English first division   364  Domestic league
# 2  Spanish first division   795  Domestic league
# 3   French first division   412  Domestic league
# 4   German first division   426  Domestic league
#
#                                                 area  type
# 0  {'name': 'Italy', 'id': '380', 'alpha3code': '...  club
# 1  {'name': 'England', 'id': '0', 'alpha3code': '...  club
# 2  {'name': 'Spain', 'id': '724', 'alpha3code': '...  club
# 3  {'name': 'France', 'id': '250', 'alpha3code': ...  club
# 4  {'name': 'Germany', 'id': '276', 'alpha3code':...  club

# %%
# we only need the name and wyId
competitions.drop(['format','area','type'], axis=1, inplace=True)

# rename wyId to teamId
competitions.rename({'wyId': 'competitionId'}, axis=1, inplace=True)

# %%
# creating a dictionary to use replace teamIds with names in the primary dataframe
competitionName = competitions.set_index('competitionId').to_dict()['name']

# use the dictionary to remap the competition name to the competitionId in the soccer dataframe
soccer.replace({'competitionId':competitionName}, inplace=True)

# %% [markdown]
# ## 3. Clean up the final dataframe
#
# We will remove the columns that are not necessary to my analysis, and update the positions column to create a specific x/y coordinate columns relative to the field grid.

# %%
# drop the columns that we don't need
soccer.drop(['status','roundId','seasonId','dateutc','venue',
             'matchId','label','date','referees','duration',
             'id','tags','teamsData'], axis=1, inplace=True)

# %% [markdown]
# Due to the fact that this dataset includes international players from the World Cup who do not play in the European leagues we are querying, we will have some N/A values. I am just going to drop these before moving forward.

# %%
soccer.dropna(inplace=True)

# %%
soccer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3440476 entries, 0 to 3714544
# Data columns (total 13 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   gameweek       float64
#  1   winner         object
#  2   competitionId  object
#  3   eventId        float64
#  4   subEventName   object
#  5   positions      object
#  6   eventName      object
#  7   teamId         object
#  8   matchPeriod    object
#  9   eventSec       float64
#  10  subEventId     object
#  11  lastName       object
#  12  role           object
# dtypes: float64(3), object(10)
# memory usage: 367.5+ MB

# %% [markdown]
# ### 3.1 Create coordinate columns

# %%
# convert position into an x and y column for plotting purposes
# retrieved from: https://github.com/Friends-of-Tracking-Data-FoTD/mapping-match-events-in-Python/blob/master/data_exploration.ipynb

soccer['x'] = [x[0]['x'] for x in soccer['positions']]
soccer['y'] = [x[0]['y'] for x in soccer['positions']]

# update the x/y records to account for the fact they are a percentage of the field. 80% on y and 120% on x
soccer['x'] = (soccer['x']/100)*120
soccer['y'] = (soccer['y']/100)*80

# %%
soccer.describe()
# Out:
#            gameweek       eventId      eventSec             x             y
# count  3.440476e+06  3.440476e+06  3.440476e+06  3.440476e+06  3.440476e+06
# mean   1.926766e+01  5.694628e+00  1.395034e+03  5.874610e+01  3.997302e+01
# std    1.079841e+01  3.141586e+00  8.357973e+02  2.962486e+01  2.423663e+01
# min    1.000000e+00  1.000000e+00  0.000000e+00 -1.200000e+00  0.000000e+00
# 25%    1.000000e+01  1.000000e+00  6.644043e+02  3.600000e+01  1.840000e+01
# 50%    1.900000e+01  8.000000e+00  1.380117e+03  5.640000e+01  4.000000e+01
# 75%    2.900000e+01  8.000000e+00  2.115222e+03  8.160000e+01  6.160000e+01
# max    3.800000e+01  1.000000e+01  3.537356e+03  1.200000e+02  8.080000e+01

# %% [markdown]
# We have at least one record where the x-value is negative and one where the y-value is greater than 80. We need to fix this.

# %%
soccer[soccer.x < 0]
# Out:
#         gameweek winner           competitionId  eventId subEventName  \
# 909196       9.0  Lazio  Italian first division      7.0        Touch
#
#                                        positions           eventName teamId  \
# 909196  [{'y': 47, 'x': -1}, {'y': 12, 'x': 69}]  Others on the ball  Lazio
#
#        matchPeriod     eventSec subEventId   lastName role    x     y
# 909196          2H  2753.190257         72  Strakosha   GK -1.2  37.6

# %%
soccer[soccer.y > 80]
# Out:
#          gameweek winner          competitionId  eventId subEventName  \
# 1570071      21.0      0  German first division      8.0  Simple pass
#
#                                          positions eventName      teamId  \
# 1570071  [{'y': 101, 'x': 28}, {'y': 95, 'x': 18}]      Pass  Hertha BSC
#
#         matchPeriod     eventSec subEventId lastName role     x     y
# 1570071          1H  1660.632434         85  Pekarík   DF  33.6  80.8

# %%
soccer.loc[(soccer['x'] < 0), 'x'] = 0
soccer.loc[(soccer['y'] > 80), 'y'] = 80

# %% [markdown]
# ### 3.2 Create positional grids
#
# We will grid out the soccer pitch into 12 sections and assign each event to a section 0-15 based on the coordinates.
#
# #### xGrids:
# ####                       0-30
# ####                     31-60
# ####                     61-90
# ####                     91-120
# #### yGrids:
# ####                       0-20
# ####                     21-40
# ####                     41-60
# ####                     61-80

# %%
soccer["xGrid"] = np.nan
soccer["yGrid"] = np.nan
soccer["positionGrid"] = np.nan

# create four categories for positional x
soccer.loc[(soccer['x'] <= 30), 'xGrid'] = 0
soccer.loc[(soccer['x'] > 30) & (soccer['x'] <= 60), 'xGrid'] = 1
soccer.loc[(soccer['x'] > 60) & (soccer['x'] <= 90), 'xGrid'] = 2
soccer.loc[(soccer['x'] > 90) & (soccer['x'] <= 120), 'xGrid'] = 3

# create four categories for positional y
soccer.loc[(soccer['y'] <= 20), 'yGrid'] = 0
soccer.loc[(soccer['y'] > 20) & (soccer['y'] <= 40), 'yGrid'] = 1
soccer.loc[(soccer['y'] > 40) & (soccer['y'] <= 60), 'yGrid'] = 2
soccer.loc[(soccer['y'] > 60) & (soccer['y'] <= 80), 'yGrid'] = 3

# %%
# populate the positional categories in the positionGrid field
soccer.loc[(soccer['xGrid'] == 0) & (soccer['yGrid'] == 0), 'positionGrid'] = 0
soccer.loc[(soccer['xGrid'] == 0) & (soccer['yGrid'] == 1), 'positionGrid'] = 1
soccer.loc[(soccer['xGrid'] == 0) & (soccer['yGrid'] == 2), 'positionGrid'] = 2
soccer.loc[(soccer['xGrid'] == 0) & (soccer['yGrid'] == 3), 'positionGrid'] = 3
soccer.loc[(soccer['xGrid'] == 1) & (soccer['yGrid'] == 0), 'positionGrid'] = 4
soccer.loc[(soccer['xGrid'] == 1) & (soccer['yGrid'] == 1), 'positionGrid'] = 5
soccer.loc[(soccer['xGrid'] == 1) & (soccer['yGrid'] == 2), 'positionGrid'] = 6
soccer.loc[(soccer['xGrid'] == 1) & (soccer['yGrid'] == 3), 'positionGrid'] = 7
soccer.loc[(soccer['xGrid'] == 2) & (soccer['yGrid'] == 0), 'positionGrid'] = 8
soccer.loc[(soccer['xGrid'] == 2) & (soccer['yGrid'] == 1), 'positionGrid'] = 9
soccer.loc[(soccer['xGrid'] == 2) & (soccer['yGrid'] == 2), 'positionGrid'] = 10
soccer.loc[(soccer['xGrid'] == 2) & (soccer['yGrid'] == 3), 'positionGrid'] = 11
soccer.loc[(soccer['xGrid'] == 3) & (soccer['yGrid'] == 0), 'positionGrid'] = 12
soccer.loc[(soccer['xGrid'] == 3) & (soccer['yGrid'] == 1), 'positionGrid'] = 13
soccer.loc[(soccer['xGrid'] == 3) & (soccer['yGrid'] == 2), 'positionGrid'] = 14
soccer.loc[(soccer['xGrid'] == 3) & (soccer['yGrid'] == 3), 'positionGrid'] = 15

# %%
# convert our positionGrid to categorical
soccer["positionGrid"] = soccer["positionGrid"].astype('category')

# %%
# drop the yGrid and xGrid series as they were just to populate the positionGrid
soccer.drop(['xGrid', 'yGrid', 'positions'], axis=1, inplace=True)

# %% [markdown]
# ### 3.3 Address missing values

# %% [markdown]
# I think that we do have a problem with eventId = "Offside". I do not think that this includes a subevent and as a result we will end up with null values. If we look at the unique values for subevents we see a ''. This is Offsides, I am going to populate this value to equate the the event ID

# %%
soccer.subEventId.unique()
# Out:
# array([85, 72, 13, 20, 11, 12, '', 10, 86, 100, 70, 23, 36, 82, 80, 83,
#        21, 84, 71, 24, 31, 22, 30, 33, 32, 26, 35, 25, 34, 91, 40, 81, 90,
#        27, 50, 51], dtype=object)

# %%
soccer.loc[93]
# Out:
# gameweek                             36
# winner                          Sevilla
# competitionId    Spanish first division
# eventId                               6
# subEventName
# eventName                       Offside
# teamId                    Real Sociedad
# matchPeriod                          2H
# eventSec                        1858.39
# subEventId
# lastName                  Jiménez López
# role                                 FW
# x                                  88.8
# y                                    44
# positionGrid                         10
# Name: 93, dtype: object

# %%
soccer.loc[(soccer['eventId'] == 6), 'subEventName'] = 'Offside'
soccer.loc[(soccer['eventId'] == 6), 'subEventId'] = 6

# %%
soccer.isna().sum()
# Out:
# gameweek         0
# winner           0
# competitionId    0
# eventId          0
# subEventName     0
# eventName        0
# teamId           0
# matchPeriod      0
# eventSec         0
# subEventId       0
# lastName         0
# role             0
# x                0
# y                0
# positionGrid     0
# dtype: int64

# %% [markdown]
# ## 4. Export to csv

# %%
# Export our data frame to a csv to utilize in our analysis
soccer.to_csv('soccer.csv', index=False)

# %%
soccer.head()
# Out:
#    gameweek     winner           competitionId  eventId subEventName  \
# 0      38.0  Barcelona  Spanish first division      8.0  Simple pass
# 1      38.0  Barcelona  Spanish first division      8.0  Simple pass
# 2      38.0  Barcelona  Spanish first division      8.0  Simple pass
# 3      38.0  Barcelona  Spanish first division      8.0  Simple pass
# 4      38.0  Barcelona  Spanish first division      8.0  Simple pass
#
#   eventName         teamId matchPeriod    eventSec subEventId       lastName  \
# 0      Pass  Real Sociedad          1H    1.005442         85  Jiménez López
# 1      Pass  Real Sociedad          1H   26.009290         85  Jiménez López
# 2      Pass  Real Sociedad          1H   97.700752         85  Jiménez López
# 3      Pass  Real Sociedad          1H  132.889252         85  Jiménez López
# 4      Pass  Real Sociedad          1H  265.013504         85  Jiménez López
#
#   role     x     y positionGrid
# 0   FW  58.8  40.8          6.0
# 1   FW  86.4  67.2         11.0
# 2   FW  67.2  59.2         10.0
# 3   FW  68.4  66.4         11.0
# 4   FW  98.4  75.2         15.0
